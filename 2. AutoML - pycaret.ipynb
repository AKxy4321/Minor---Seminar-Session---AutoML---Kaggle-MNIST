# %%
#%pip install -q scikit-learn pandas pycaret pycaret[models]

# %%
import pandas as pd
from pycaret.classification import *

# Load the Breast Cancer dataset
from sklearn.datasets import load_iris
data = load_iris()
X, y = data.data, data.target

# %%
# Convert X and y to a pandas DataFrame
df = pd.DataFrame(data=X, columns=data.feature_names)
df['target'] = y

# %%
# Create a PyCaret experiment
exp1 = setup(data=df)
# Out:
# <style type="text/css">
# #T_a821f_row8_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_a821f">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_a821f_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_a821f_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a821f_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_a821f_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_a821f_row0_col1" class="data row0 col1" >8963</td>
#     </tr>
#     <tr>
#       <th id="T_a821f_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_a821f_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_a821f_row1_col1" class="data row1 col1" >target</td>
#     </tr>
#     <tr>
#       <th id="T_a821f_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_a821f_row2_col0" class="data row2 col0" >Target type</td>
#       <td id="T_a821f_row2_col1" class="data row2 col1" >Multiclass</td>
#     </tr>
#     <tr>
#       <th id="T_a821f_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_a821f_row3_col0" class="data row3 col0" >Original data shape</td>
#       <td id="T_a821f_row3_col1" class="data row3 col1" >(150, 5)</td>
#     </tr>
#     <tr>
#       <th id="T_a821f_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_a821f_row4_col0" class="data row4 col0" >Transformed data shape</td>
#       <td id="T_a821f_row4_col1" class="data row4 col1" >(150, 5)</td>
#     </tr>
#     <tr>
#       <th id="T_a821f_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_a821f_row5_col0" class="data row5 col0" >Transformed train set shape</td>
#       <td id="T_a821f_row5_col1" class="data row5 col1" >(105, 5)</td>
#     </tr>
#     <tr>
#       <th id="T_a821f_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_a821f_row6_col0" class="data row6 col0" >Transformed test set shape</td>
#       <td id="T_a821f_row6_col1" class="data row6 col1" >(45, 5)</td>
#     </tr>
#     <tr>
#       <th id="T_a821f_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_a821f_row7_col0" class="data row7 col0" >Numeric features</td>
#       <td id="T_a821f_row7_col1" class="data row7 col1" >4</td>
#     </tr>
#     <tr>
#       <th id="T_a821f_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_a821f_row8_col0" class="data row8 col0" >Preprocess</td>
#       <td id="T_a821f_row8_col1" class="data row8 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_a821f_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_a821f_row9_col0" class="data row9 col0" >Imputation type</td>
#       <td id="T_a821f_row9_col1" class="data row9 col1" >simple</td>
#     </tr>
#     <tr>
#       <th id="T_a821f_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_a821f_row10_col0" class="data row10 col0" >Numeric imputation</td>
#       <td id="T_a821f_row10_col1" class="data row10 col1" >mean</td>
#     </tr>
#     <tr>
#       <th id="T_a821f_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_a821f_row11_col0" class="data row11 col0" >Categorical imputation</td>
#       <td id="T_a821f_row11_col1" class="data row11 col1" >mode</td>
#     </tr>
#     <tr>
#       <th id="T_a821f_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_a821f_row12_col0" class="data row12 col0" >Fold Generator</td>
#       <td id="T_a821f_row12_col1" class="data row12 col1" >StratifiedKFold</td>
#     </tr>
#     <tr>
#       <th id="T_a821f_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_a821f_row13_col0" class="data row13 col0" >Fold Number</td>
#       <td id="T_a821f_row13_col1" class="data row13 col1" >10</td>
#     </tr>
#     <tr>
#       <th id="T_a821f_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_a821f_row14_col0" class="data row14 col0" >CPU Jobs</td>
#       <td id="T_a821f_row14_col1" class="data row14 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_a821f_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_a821f_row15_col0" class="data row15 col0" >Use GPU</td>
#       <td id="T_a821f_row15_col1" class="data row15 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_a821f_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_a821f_row16_col0" class="data row16 col0" >Log Experiment</td>
#       <td id="T_a821f_row16_col1" class="data row16 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_a821f_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_a821f_row17_col0" class="data row17 col0" >Experiment Name</td>
#       <td id="T_a821f_row17_col1" class="data row17 col1" >clf-default-name</td>
#     </tr>
#     <tr>
#       <th id="T_a821f_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_a821f_row18_col0" class="data row18 col0" >USI</td>
#       <td id="T_a821f_row18_col1" class="data row18 col1" >0601</td>
#     </tr>
#   </tbody>
# </table>

# %%
# Compare models and tune hyperparameters
best_model = compare_models()
# Out:
# <style type="text/css">
# #T_53007 th {
#   text-align: left;
# }
# #T_53007_row0_col0, #T_53007_row0_col5, #T_53007_row1_col0, #T_53007_row1_col2, #T_53007_row1_col4, #T_53007_row1_col6, #T_53007_row1_col7, #T_53007_row2_col0, #T_53007_row2_col1, #T_53007_row2_col2, #T_53007_row2_col3, #T_53007_row2_col4, #T_53007_row2_col5, #T_53007_row2_col6, #T_53007_row2_col7, #T_53007_row3_col0, #T_53007_row3_col1, #T_53007_row3_col2, #T_53007_row3_col3, #T_53007_row3_col4, #T_53007_row3_col5, #T_53007_row3_col6, #T_53007_row3_col7, #T_53007_row4_col0, #T_53007_row4_col1, #T_53007_row4_col2, #T_53007_row4_col3, #T_53007_row4_col4, #T_53007_row4_col5, #T_53007_row4_col6, #T_53007_row4_col7, #T_53007_row5_col0, #T_53007_row5_col1, #T_53007_row5_col2, #T_53007_row5_col3, #T_53007_row5_col4, #T_53007_row5_col5, #T_53007_row5_col6, #T_53007_row5_col7, #T_53007_row6_col0, #T_53007_row6_col1, #T_53007_row6_col2, #T_53007_row6_col3, #T_53007_row6_col4, #T_53007_row6_col5, #T_53007_row6_col6, #T_53007_row6_col7, #T_53007_row7_col0, #T_53007_row7_col1, #T_53007_row7_col2, #T_53007_row7_col3, #T_53007_row7_col4, #T_53007_row7_col5, #T_53007_row7_col6, #T_53007_row7_col7, #T_53007_row8_col0, #T_53007_row8_col1, #T_53007_row8_col2, #T_53007_row8_col3, #T_53007_row8_col4, #T_53007_row8_col5, #T_53007_row8_col6, #T_53007_row8_col7, #T_53007_row9_col0, #T_53007_row9_col1, #T_53007_row9_col2, #T_53007_row9_col3, #T_53007_row9_col4, #T_53007_row9_col5, #T_53007_row9_col6, #T_53007_row9_col7, #T_53007_row10_col0, #T_53007_row10_col1, #T_53007_row10_col3, #T_53007_row10_col4, #T
row2_col0" class="data row2 col0" >K Neighbors Classifier</td>
#       <td id="T_53007_row2_col1" class="data row2 col1" >0.9709</td>
#       <td id="T_53007_row2_col2" class="data row2 col2" >0.9891</td>
#       <td id="T_53007_row2_col3" class="data row2 col3" >0.9709</td>
#       <td id="T_53007_row2_col4" class="data row2 col4" >0.9772</td>
#       <td id="T_53007_row2_col5" class="data row2 col5" >0.9700</td>
#       <td id="T_53007_row2_col6" class="data row2 col6" >0.9557</td>
#       <td id="T_53007_row2_col7" class="data row2 col7" >0.9595</td>
#       <td id="T_53007_row2_col8" class="data row2 col8" >0.3070</td>
#     </tr>
#     <tr>
#       <th id="T_53007_level0_row3" class="row_heading level0 row3" >ada</th>
#       <td id="T_53007_row3_col0" class="data row3 col0" >Ada Boost Classifier</td>
#       <td id="T_53007_row3_col1" class="data row3 col1" >0.9618</td>
#       <td id="T_53007_row3_col2" class="data row3 col2" >0.9879</td>
#       <td id="T_53007_row3_col3" class="data row3 col3" >0.9618</td>
#       <td id="T_53007_row3_col4" class="data row3 col4" >0.9704</td>
#       <td id="T_53007_row3_col5" class="data row3 col5" >0.9610</td>
#       <td id="T_53007_row3_col6" class="data row3 col6" >0.9422</td>
#       <td id="T_53007_row3_col7" class="data row3 col7" >0.9471</td>
#       <td id="T_53007_row3_col8" class="data row3 col8" >0.0340</td>
#     </tr>
#     <tr>
#       <th id="T_53007_level0_row4" class="row_heading level0 row4" >gbc</th>
#       <td id="T_53007_row4_col0" class="data row4 col0" >Gradient Boosting Classifier</td>
#       <td id="T_53007_row4_col1" class="data row4 col1" >0.9618</td>
#       <td id="T_53007_row4_col2" class="data row4 col2" >0.9791</td>
#       <td id="T_53007_row4_col3" class="data row4 col3" >0.9618</td>
#       <td id="T_53007_row4_col4" class="data row4 col4" >0.9704</td>
#       <td id="T_53007_row4_col5" class="data row4 col5" >0.9610</td>
#       <td id="T_53007_row4_col6" class="data row4 col6" >0.9422</td>
#       <td id="T_53007_row4_col7" class="data row4 col7" >0.9471</td>
#       <td id="T_53007_row4_col8" class="data row4 col8" >0.0660</td>
#     </tr>
#     <tr>
#       <th id="T_53007_level0_row5" class="row_heading level0 row5" >xgboost</th>
#       <td id="T_53007_row5_col0" class="data row5 col0" >Extreme Gradient Boosting</td>
#       <td id="T_53007_row5_col1" class="data row5 col1" >0.9618</td>
#       <td id="T_53007_row5_col

# %%
# Evaluate the best model
evaluate_model(best_model)
# Out:
# interactive(children=(ToggleButtons(description='Plot Type:', icons=('',), options=(('Pipeline Plot', 'pipelin…

# %%
# Finalize the best model using the entire dataset
final_model = finalize_model(best_model)

# %%
# Save the model
save_model(final_model, 'iris_classification_model')
# Out:
# Transformation Pipeline and Model Successfully Saved
# (Pipeline(memory=Memory(location=None),
#           steps=[('numerical_imputer',
#                   TransformerWrapper(exclude=None,
#                                      include=['sepal length (cm)',
#                                               'sepal width (cm)',
#                                               'petal length (cm)',
#                                               'petal width (cm)'],
#                                      transformer=SimpleImputer(add_indicator=False,
#                                                                copy=True,
#                                                                fill_value=None,
#                                                                keep_empty_features=False,
#                                                                missing_values=nan,
#                                                                strategy='mean'))),
#                  ('categorical_imputer',
#                   TransformerWr...
#                                                                copy=True,
#                                                                fill_value=None,
#                                                                keep_empty_features=False,
#                                                                missing_values=nan,
#                                                                strategy='most_frequent'))),
#                  ('clean_column_names',
#                   TransformerWrapper(exclude=None, include=None,
#                                      transformer=CleanColumnNames(match='[\\]\\[\\,\\{\\}\\"\\:]+'))),
#                  ('actual_estimator',
#                   QuadraticDiscriminantAnalysis(priors=None, reg_param=0.0,
#                                                 store_covariance=False,
#                                                 tol=0.0001))],
#           verbose=False),
#  'iris_classification_model.pkl')

# %%
from pycaret.classification import load_model, predict_model
from sklearn.metrics import accuracy_score

# Load the saved model
model = load_model('iris_classification_model')

# Perform inference on new data
new_data = pd.DataFrame({
    'sepal length (cm)': [5.1, 6.2, 7.3],
    'sepal width (cm)': [3.5, 2.9, 3.3],
    'petal length (cm)': [1.4, 4.5, 6.3],
    'petal width (cm)': [0.2, 1.4, 2.4],
    'actual_label': [0, 1, 2]  # Assuming these are the true labels
})

predictions = predict_model(model, data=new_data)
print(predictions)

# Calculate accuracy
accuracy = accuracy_score(new_data['actual_label'], predictions['prediction_label'])

print("Accuracy:", accuracy)
# Out:
# Transformation Pipeline and Model Successfully Loaded
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                5.1               3.5                1.4               0.2
# 1                6.2               2.9                4.5               1.4
# 2                7.3               3.3                6.3               2.4
#
#    actual_label  prediction_label  prediction_score
# 0             0                 0             1.000
# 1             1                 1             0.999
# 2             2                 2             1.000
# Accuracy: 1.0
